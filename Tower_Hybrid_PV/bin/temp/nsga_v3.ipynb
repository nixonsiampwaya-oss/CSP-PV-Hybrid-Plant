# %%
# ga_optimize_hybrid.py
from __future__ import annotations
import random
import math
from functools import lru_cache
from datetime import datetime, timezone
from pathlib import Path
import csv

from deap import base, creator, tools, algorithms  # noqa: F401 (algorithms unused but fine)

# ---- your model ----
from model_system import run_hybrid_summary

# =========================
# Search space & utilities
# =========================
# Bounds (tune if you have better priors)
BOUNDS = [
    (50_000.0, 300_000.0),   # desired_array_size [kWdc]
    (50.0, 200.0),           # P_ref [MWe]
    (0.0, 16.0),             # t_TES_hours [h]
    (1.0, 5.0),              # solarm [-]
]

# Coarse grid helps stability + cache hit-rate
RESOLUTION = [500.0, 1.0, 0.5, 0.1]  # rounding step for each variable

def clamp(val, lo, hi):
    return max(lo, min(hi, val))

def repair(ind):
    """Keep individuals inside bounds & snap to a grid for stability + caching."""
    for i, (lo, hi) in enumerate(BOUNDS):
        step = RESOLUTION[i]
        ind[i] = clamp(round(ind[i] / step) * step, lo, hi)
    return ind

# =========================
# Objective extraction
# =========================
def _get_num(d: dict, *cand_keys, default=None):
    for k in cand_keys:
        if k in d and d[k] is not None:
            try:
                return float(d[k])
            except Exception:
                pass
    return default

# -------------------------
# Trial logging (ALL calls)
# -------------------------
_TRIAL_LOG = []
_CURRENT_GEN = -1   # updated in main() loop before evaluations
_SEEN_PARAMS = set()  # tracks evaluated (das, pref, th, sm)

def _log_trial(gen, das, pref, th, sm,
               ppa, cf, fit_ppa, fit_cf,
               status, note="",
               lcoe=None, annual_rev=None, cf_pb=None,
               pv_mwh=None, csp_mwh=None):
    _TRIAL_LOG.append({
        "gen": gen,
        "desired_array_size": das,
        "P_ref": pref,
        "t_TES_hours": th,
        "solarm": sm,
        "PPA_USD_per_MWh": ppa,
        "CF_hybrid": cf,
        "CF_pb": cf_pb,
        "LCOE": lcoe,
        "Annual_Revenue_USD": annual_rev,
        "PV_to_Grid_MWh": pv_mwh,
        "CSP_to_Grid_MWh": csp_mwh,
        "fitness_PPA": fit_ppa,     # same as PPA unless penalized
        "fitness_CF": fit_cf,       # same as CF unless penalized
        "status": status,
        "note": note,
        "timestamp": datetime.now(timezone.utc).isoformat()
    })

def _write_trials_csv(path: str | Path):
    path = Path(path)
    path.parent.mkdir(parents=True, exist_ok=True)
    keys = [
        "gen","desired_array_size","P_ref","t_TES_hours","solarm",
        "PPA_USD_per_MWh","CF_hybrid","CF_pb","LCOE",
        "Annual_Revenue_USD","PV_to_Grid_MWh","CSP_to_Grid_MWh",
        "fitness_PPA","fitness_CF","status","note","timestamp"
    ]
    with path.open("w", newline="") as f:
        writer = csv.DictWriter(f, fieldnames=keys)
        writer.writeheader()
        for row in _TRIAL_LOG:
            writer.writerow(row)

# =========================
# Cached evaluator
# =========================
@lru_cache(maxsize=2048)
def _evaluate_cached(desired_array_size, P_ref, t_TES_hours, solarm):
    """
    Evaluate one design.
    Objective: minimize PPA, maximize CF_hybrid.
    Returns (fitness_PPA, fitness_CF, result_dict, status)
    """
    try:
        res = run_hybrid_summary(
            desired_array_size=desired_array_size,
            P_ref=P_ref,
            t_TES_hours=t_TES_hours,
            solarm=solarm,
        )
        # Some implementations might return (dict,) — normalize:
        if isinstance(res, tuple) and len(res) == 1 and isinstance(res[0], dict):
            res = res[0]

        if not isinstance(res, dict):
            # Unknown structure -> hard penalty
            PENALTY_MAX, PENALTY_MIN = 1e9, -1e9
            return (PENALTY_MAX, PENALTY_MIN, {}, "penalty_bad_return")

        ppa = _get_num(res, "PPA", default=None)
        cf  = _get_num(res, "CF_hybrid", default=None)

        PENALTY_MAX, PENALTY_MIN = 1e9, -1e9
        if ppa is None or not math.isfinite(ppa):
            return (PENALTY_MAX, PENALTY_MIN, res, "penalty_missing_ppa")
        if cf is None or not math.isfinite(cf):
            return (ppa, PENALTY_MIN, res, "penalty_missing_cf")

        # Fitness = (PPA, CF) with weights=(-1, +1)
        return (ppa, cf, res, "ok")

    except Exception as e:
        PENALTY_MAX, PENALTY_MIN = 1e9, -1e9
        return (PENALTY_MAX, PENALTY_MIN, {}, f"exception:{type(e).__name__}")

def evaluate(individual):
    """DEAP evaluate wrapper: rounds, caches, logs full results."""
    repair(individual)
    das, pref, th, sm = individual

    # round to evaluation grid (hashable for cache + dedup)
    das = round(das / RESOLUTION[0]) * RESOLUTION[0]
    pref = round(pref / RESOLUTION[1]) * RESOLUTION[1]
    th   = round(th   / RESOLUTION[2]) * RESOLUTION[2]
    sm   = round(sm   / RESOLUTION[3]) * RESOLUTION[3]

    key = (das, pref, th, sm)
    note = "repeat" if key in _SEEN_PARAMS else "new"
    _SEEN_PARAMS.add(key)

    fit_ppa, fit_cf, res_dict, status = _evaluate_cached(das, pref, th, sm)

    # pull extra fields for logging (if present)
    ppa   = res_dict.get("PPA")
    cf    = res_dict.get("CF_hybrid")
    lcoe  = res_dict.get("LCOE")
    rev   = res_dict.get("Annual_Revenue")
    pv_mw = res_dict.get("PV_to_Grid_MWh")
    csp_mw= res_dict.get("CSP_to_Grid_MWh")
    cf_pb = res_dict.get("CF_pb")

    _log_trial(
        gen=_CURRENT_GEN,
        das=das, pref=pref, th=th, sm=sm,
        ppa=ppa, cf=cf,
        fit_ppa=fit_ppa, fit_cf=fit_cf,
        status=status, note=note,
        lcoe=lcoe, annual_rev=rev, cf_pb=cf_pb,
        pv_mwh=pv_mw, csp_mwh=csp_mw
    )

    return (fit_ppa, fit_cf)

# ================
# DEAP boilerplate
# ================
# Two-objective: (min PPA, max CF)
try:
    creator.FitnessMin2
except AttributeError:
    creator.create("FitnessMin2", base.Fitness, weights=(-1.0, 1.0))
try:
    creator.Individual
except AttributeError:
    creator.create("Individual", list, fitness=creator.FitnessMin2)

toolbox = base.Toolbox()

def _rand_between(lo, hi):
    return random.uniform(lo, hi)

for i, (lo, hi) in enumerate(BOUNDS):
    toolbox.register(f"attr_{i}", _rand_between, lo, hi)

toolbox.register(
    "individual",
    tools.initCycle,
    creator.Individual,
    (toolbox.attr_0, toolbox.attr_1, toolbox.attr_2, toolbox.attr_3),
    n=1,
)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("evaluate", evaluate)

# SBX crossover + polynomial mutation for bounded reals
toolbox.register("mate", tools.cxSimulatedBinaryBounded,
                 low=[b[0] for b in BOUNDS], up=[b[1] for b in BOUNDS], eta=15.0)
toolbox.register("mutate", tools.mutPolynomialBounded,
                 low=[b[0] for b in BOUNDS], up=[b[1] for b in BOUNDS], eta=20.0, indpb=0.25)
toolbox.register("select", tools.selNSGA2)

def main(seed: int = 42,
         pop_size: int = 24,
         ngen: int = 30,
         cxpb: float = 0.85,
         mutpb: float = 0.25,
         log_csv: str | Path = "ga_trials.csv"):
    global _CURRENT_GEN
    random.seed(seed)

    pop = toolbox.population(n=pop_size)
    hof = tools.ParetoFront()  # non-dominated set

    # Stats (track objectives)
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("min_PPA", lambda fits: min(f[0] for f in fits))
    stats.register("best_CF", lambda fits: max(f[1] for f in fits))

    # Initial evaluation (NSGA-II requires valid fitness before first select)
    _CURRENT_GEN = 0
    for ind in pop:
        repair(ind)
        ind.fitness.values = toolbox.evaluate(ind)

    # Sort & crowding distance
    pop = toolbox.select(pop, len(pop))
    hof.update(pop)

    # Evolve
    for gen in range(1, ngen + 1):
        _CURRENT_GEN = gen

        # Variation
        offspring = tools.selTournamentDCD(pop, len(pop))
        offspring = [toolbox.clone(ind) for ind in offspring]

        for i in range(0, len(offspring), 2):
            if random.random() < cxpb and i + 1 < len(offspring):
                toolbox.mate(offspring[i], offspring[i + 1])
                repair(offspring[i]); repair(offspring[i + 1])
                if hasattr(offspring[i].fitness, "values"):
                    del offspring[i].fitness.values
                if hasattr(offspring[i + 1].fitness, "values"):
                    del offspring[i + 1].fitness.values

        for i in range(len(offspring)):
            if random.random() < mutpb:
                toolbox.mutate(offspring[i])
                repair(offspring[i])
                if hasattr(offspring[i].fitness, "values"):
                    del offspring[i].fitness.values

        # Evaluate invalid
        invalid = [ind for ind in offspring if not ind.fitness.valid]
        for ind in invalid:
            ind.fitness.values = toolbox.evaluate(ind)

        # Combine + select
        pop = toolbox.select(pop + offspring, pop_size)
        hof.update(pop)

        # Stats
        record = stats.compile(pop)
        print(f"Gen {gen:>3}/{ngen} | min PPA: {record['min_PPA']:.3f} USD/MWh | "
              f"best CF: {record['best_CF']:.4f}")

    # Report final Pareto front
    print("\n=== Pareto front (PPA, CF) ===")
    for ind in hof:
        ppa, cf = ind.fitness.values
        print(
            f"das={ind[0]:.0f} kWdc | P_ref={ind[1]:.1f} MWe | TES={ind[2]:.1f} h | SM={ind[3]:.1f} "
            f"| PPA={ppa:.2f} USD/MWh | CF={cf:.4f}"
        )

    # Best-by-PPA convenience
    best_by_ppa = min(hof, key=lambda x: x.fitness.values[0])
    ppa, cf = best_by_ppa.fitness.values
    print("\nBest-by-PPA candidate:")
    print(
        f"das={best_by_ppa[0]:.0f} kWdc | P_ref={best_by_ppa[1]:.1f} MWe | TES={best_by_ppa[2]:.1f} h | SM={best_by_ppa[3]:.1f} "
        f"| PPA={ppa:.2f} USD/MWh | CF={cf:.4f}"
    )

    # ---- write ALL trials to CSV ----
    _write_trials_csv(log_csv)
    print(f"\nSaved ALL trials to: {Path(log_csv).resolve()}")

    return pop, hof

if __name__ == "__main__":
    # NOTE (Windows): keep GA execution inside __main__ guard.
    main(
        seed=123,
        pop_size=40,    # lower if each evaluation is slow; raise for broader search
        ngen=20,        # increase for better convergence
        cxpb=0.9,
        mutpb=0.3,
        log_csv="ga_trials.csv"
    )
# Out:
# ✅ Total CAPEX           : 450.48 MUSD
# ✅ Total OPEX            : 4.24 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 63,000.0000
# P_ref                    : 63.0000
# t_TES_hours              : 6.5000
# PPA                      : 49.9680
# CF_hybrid                : 0.2540
# CF_pb                    : 0.2110
# LCOE                     : 144.8115
# Annual_Revenue           : 18,232,369.2766
# PV_to_Grid_MWh           : 106,047.9217
# CSP_to_Grid_MWh          : 116,470.8885
# ✅ Total CAPEX           : 1467.73 MUSD
# ✅ Total OPEX            : 11.45 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 275,500.0000
# P_ref                    : 56.0000
# t_TES_hours              : 8.5000
# PPA                      : 85.5380
# CF_hybrid                : 0.5042
# CF_pb                    : 0.2840
# LCOE                     : 232.3494
# Annual_Revenue           : 57,035,036.5020
# PV_to_Grid_MWh           : 302,343.5798
# CSP_to_Grid_MWh          : 139,317.6683
# ✅ Total CAPEX           : 1450.25 MUSD
# ✅ Total OPEX            : 11.68 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 263,000.0000
# P_ref                    : 74.0000
# t_TES_hours              : 5.5000
# PPA                      : 84.5567
# CF_hybrid                : 0.4904
# CF_pb                    : 0.2017
# LCOE                     : 236.8757
# Annual_Revenue           : 56,720,011.0218
# PV_to_Grid_MWh           : 298,824.2201
# CSP_to_Grid_MWh          : 130,776.0390
# ✅ Total CAPEX           : 555.84 MUSD
# ✅ Total OPEX            : 4.74 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 111,500.0000
# P_ref                    : 50.0000
# t_TES_hours              : 7.0000
# PPA                      : 56.0216
# CF_hybrid                : 0.3132
# CF_pb                    : 0.1975
# LCOE                     : 143.1259
# Annual_Revenue           : 22,004,000.3726
# PV_to_Grid_MWh           : 187,854.0449
# CSP_to_Grid_MWh          : 86,499.7423
# ✅ Total CAPEX           : 1044.32 MUSD
# ✅ Total OPEX            : 8.26 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 199,500.0000
# P_ref                    : 60.0000
# t_TES_hours              : 5.0000
# PPA                      : 71.5964
# CF_hybrid                : 0.4349
# CF_pb                    : 0.2046
# LCOE                     : 191.9472
# Annual_Revenue           : 40,696,116.9555
# PV_to_Grid_MWh           : 273,455.6831
# CSP_to_Grid_MWh          : 107,536.6691
# ✅ Total CAPEX           : 1608.32 MUSD
# ✅ Total OPEX            : 11.42 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 276,500.0000
# P_ref                    : 64.0000
# t_TES_hours              : 2.5000
# PPA                      : 154.5628
# CF_hybrid                : 0.3161
# CF_pb                    : 0.1012
# LCOE                     : 401.9755
# Annual_Revenue           : 61,372,263.0862
# PV_to_Grid_MWh           : 220,229.9897
# CSP_to_Grid_MWh          : 56,710.3891
# ✅ Total CAPEX           : 937.72 MUSD
# ✅ Total OPEX            : 9.45 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 55,500.0000
# P_ref                    : 187.0000
# t_TES_hours              : 9.0000
# PPA                      : 46.7885
# CF_hybrid                : 0.5449
# CF_pb                    : 0.2343
# LCOE                     : 141.8134
# Annual_Revenue           : 38,574,481.3323
# PV_to_Grid_MWh           : 93,524.4204
# CSP_to_Grid_MWh          : 383,850.6014
# ✅ Total CAPEX           : 1776.39 MUSD
# ✅ Total OPEX            : 14.30 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 259,500.0000
# P_ref                    : 165.0000
# t_TES_hours              : 5.5000
# PPA                      : 145.6228
# CF_hybrid                : 0.3674
# CF_pb                    : 0.0492
# LCOE                     : 387.2612
# Annual_Revenue           : 69,473,385.2355
# PV_to_Grid_MWh           : 250,684.7057
# CSP_to_Grid_MWh          : 71,176.4387
# ✅ Total CAPEX           : 983.58 MUSD
# ✅ Total OPEX            : 7.67 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 101,500.0000
# P_ref                    : 141.0000
# t_TES_hours              : 8.5000
# PPA                      : 232.2351
# CF_hybrid                : 0.1441
# CF_pb                    : 0.0224
# LCOE                     : 544.5840
# Annual_Revenue           : 38,215,774.0969
# PV_to_Grid_MWh           : 98,619.6282
# CSP_to_Grid_MWh          : 27,648.5838
# ✅ Total CAPEX           : 1035.48 MUSD
# ✅ Total OPEX            : 8.16 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 129,000.0000
# P_ref                    : 110.0000
# t_TES_hours              : 12.5000
# PPA                      : 52.2258
# CF_hybrid                : 0.5251
# CF_pb                    : 0.2539
# LCOE                     : 157.5598
# Annual_Revenue           : 40,320,817.1059
# PV_to_Grid_MWh           : 215,394.9376
# CSP_to_Grid_MWh          : 244,625.3316
# ✅ Total CAPEX           : 1547.76 MUSD
# ✅ Total OPEX            : 11.88 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 221,000.0000
# P_ref                    : 146.0000
# t_TES_hours              : 10.5000
# PPA                      : 150.6991
# CF_hybrid                : 0.3137
# CF_pb                    : 0.0471
# LCOE                     : 393.0444
# Annual_Revenue           : 59,946,733.8601
# PV_to_Grid_MWh           : 214,632.2345
# CSP_to_Grid_MWh          : 60,189.2156
# ✅ Total CAPEX           : 1079.10 MUSD
# ✅ Total OPEX            : 10.78 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 171,500.0000
# P_ref                    : 150.0000
# t_TES_hours              : 6.0000
# PPA                      : 54.1967
# CF_hybrid                : 0.5712
# CF_pb                    : 0.1852
# LCOE                     : 155.5050
# Annual_Revenue           : 44,290,236.3731
# PV_to_Grid_MWh           : 257,020.7914
# CSP_to_Grid_MWh          : 243,315.0315
# ✅ Total CAPEX           : 1508.39 MUSD
# ✅ Total OPEX            : 10.18 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 238,500.0000
# P_ref                    : 77.0000
# t_TES_hours              : 13.0000
# PPA                      : 136.3286
# CF_hybrid                : 0.3384
# CF_pb                    : 0.0965
# LCOE                     : 350.4590
# Annual_Revenue           : 57,031,316.5870
# PV_to_Grid_MWh           : 231,338.3441
# CSP_to_Grid_MWh          : 65,069.2629
# ✅ Total CAPEX           : 1189.34 MUSD
# ✅ Total OPEX            : 9.61 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 214,500.0000
# P_ref                    : 76.0000
# t_TES_hours              : 5.5000
# PPA                      : 70.7861
# CF_hybrid                : 0.4795
# CF_pb                    : 0.2091
# LCOE                     : 198.7363
# Annual_Revenue           : 46,547,134.9455
# PV_to_Grid_MWh           : 280,851.7086
# CSP_to_Grid_MWh          : 139,230.1729
# ✅ Total CAPEX           : 781.50 MUSD
# ✅ Total OPEX            : 7.01 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 68,500.0000
# P_ref                    : 119.0000
# t_TES_hours              : 9.0000
# PPA                      : 45.7093
# CF_hybrid                : 0.4339
# CF_pb                    : 0.2540
# LCOE                     : 146.1497
# Annual_Revenue           : 31,278,395.7544
# PV_to_Grid_MWh           : 115,341.6007
# CSP_to_Grid_MWh          : 264,749.2514
# ✅ Total CAPEX           : 547.39 MUSD
# ✅ Total OPEX            : 4.90 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 97,500.0000
# P_ref                    : 63.0000
# t_TES_hours              : 10.0000
# PPA                      : 55.9078
# CF_hybrid                : 0.2962
# CF_pb                    : 0.1725
# LCOE                     : 149.9335
# Annual_Revenue           : 21,896,508.2384
# PV_to_Grid_MWh           : 164,232.1129
# CSP_to_Grid_MWh          : 95,197.4499
# ✅ Total CAPEX           : 992.87 MUSD
# ✅ Total OPEX            : 6.62 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 138,000.0000
# P_ref                    : 84.0000
# t_TES_hours              : 8.5000
# PPA                      : 148.5744
# CF_hybrid                : 0.2153
# CF_pb                    : 0.0580
# LCOE                     : 362.1694
# Annual_Revenue           : 37,460,339.4208
# PV_to_Grid_MWh           : 145,914.8409
# CSP_to_Grid_MWh          : 42,661.6492
# ✅ Total CAPEX           : 1943.84 MUSD
# ✅ Total OPEX            : 14.54 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 277,500.0000
# P_ref                    : 146.0000
# t_TES_hours              : 16.0000
# PPA                      : 146.6143
# CF_hybrid                : 0.3919
# CF_pb                    : 0.0598
# LCOE                     : 394.0414
# Annual_Revenue           : 74,914,966.2828
# PV_to_Grid_MWh           : 266,824.6444
# CSP_to_Grid_MWh          : 76,506.1767
# ✅ Total CAPEX           : 1123.18 MUSD
# ✅ Total OPEX            : 9.58 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 207,500.0000
# P_ref                    : 85.0000
# t_TES_hours              : 7.5000
# PPA                      : 61.3483
# CF_hybrid                : 0.5203
# CF_pb                    : 0.2394
# LCOE                     : 174.0781
# Annual_Revenue           : 44,461,876.2078
# PV_to_Grid_MWh           : 277,518.6072
# CSP_to_Grid_MWh          : 178,284.7597
# ✅ Total CAPEX           : 1790.50 MUSD
# ✅ Total OPEX            : 15.16 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 298,000.0000
# P_ref                    : 117.0000
# t_TES_hours              : 12.0000
# PPA                      : 77.4013
# CF_hybrid                : 0.6560
# CF_pb                    : 0.2599
# LCOE                     : 219.9392
# Annual_Revenue           : 70,770,900.6716
# PV_to_Grid_MWh           : 308,214.1977
# CSP_to_Grid_MWh          : 266,399.5190
# ✅ Total CAPEX           : 621.69 MUSD
# ✅ Total OPEX            : 5.54 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 83,500.0000
# P_ref                    : 79.0000
# t_TES_hours              : 4.0000
# PPA                      : 51.7131
# CF_hybrid                : 0.3608
# CF_pb                    : 0.2535
# LCOE                     : 139.7178
# Annual_Revenue           : 24,846,426.9161
# PV_to_Grid_MWh           : 140,597.8388
# CSP_to_Grid_MWh          : 175,430.6009
# ✅ Total CAPEX           : 791.40 MUSD
# ✅ Total OPEX            : 7.80 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 118,000.0000
# P_ref                    : 115.0000
# t_TES_hours              : 6.5000
# PPA                      : 45.9745
# CF_hybrid                : 0.4808
# CF_pb                    : 0.2208
# LCOE                     : 135.2235
# Annual_Revenue           : 32,379,178.7430
# PV_to_Grid_MWh           : 198,755.4003
# CSP_to_Grid_MWh          : 222,462.1792
# ✅ Total CAPEX           : 696.16 MUSD
# ✅ Total OPEX            : 6.30 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 65,500.0000
# P_ref                    : 103.0000
# t_TES_hours              : 1.5000
# PPA                      : 72.9159
# CF_hybrid                : 0.3011
# CF_pb                    : 0.1765
# LCOE                     : 187.8492
# Annual_Revenue           : 27,923,825.3155
# PV_to_Grid_MWh           : 104,478.8647
# CSP_to_Grid_MWh          : 159,270.1368
# ✅ Total CAPEX           : 759.31 MUSD
# ✅ Total OPEX            : 6.25 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 52,000.0000
# P_ref                    : 130.0000
# t_TES_hours              : 1.0000
# PPA                      : 176.6171
# CF_hybrid                : 0.1443
# CF_pb                    : 0.0366
# LCOE                     : 422.6316
# Annual_Revenue           : 29,834,337.0148
# PV_to_Grid_MWh           : 84,701.3006
# CSP_to_Grid_MWh          : 41,690.1100
# ✅ Total CAPEX           : 1229.14 MUSD
# ✅ Total OPEX            : 12.13 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 151,000.0000
# P_ref                    : 198.0000
# t_TES_hours              : 4.0000
# PPA                      : 64.0655
# CF_hybrid                : 0.5415
# CF_pb                    : 0.1349
# LCOE                     : 186.5477
# Annual_Revenue           : 50,309,005.7596
# PV_to_Grid_MWh           : 240,370.2020
# CSP_to_Grid_MWh          : 233,950.4338
# ✅ Total CAPEX           : 1506.43 MUSD
# ✅ Total OPEX            : 11.74 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 237,500.0000
# P_ref                    : 100.0000
# t_TES_hours              : 5.5000
# PPA                      : 77.1820
# CF_hybrid                : 0.5297
# CF_pb                    : 0.1980
# LCOE                     : 226.9807
# Annual_Revenue           : 58,527,446.1874
# PV_to_Grid_MWh           : 290,512.4555
# CSP_to_Grid_MWh          : 173,464.7102
# ✅ Total CAPEX           : 2042.27 MUSD
# ✅ Total OPEX            : 16.61 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 292,500.0000
# P_ref                    : 183.0000
# t_TES_hours              : 6.5000
# PPA                      : 148.4790
# CF_hybrid                : 0.4125
# CF_pb                    : 0.0506
# LCOE                     : 397.0526
# Annual_Revenue           : 80,034,551.6209
# PV_to_Grid_MWh           : 280,276.9504
# CSP_to_Grid_MWh          : 81,042.9934
# ✅ Total CAPEX           : 1210.15 MUSD
# ✅ Total OPEX            : 10.95 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 220,000.0000
# P_ref                    : 106.0000
# t_TES_hours              : 4.0000
# PPA                      : 72.9705
# CF_hybrid                : 0.4796
# CF_pb                    : 0.1473
# LCOE                     : 204.9853
# Annual_Revenue           : 48,537,225.6141
# PV_to_Grid_MWh           : 283,328.4229
# CSP_to_Grid_MWh          : 136,808.0433
# ✅ Total CAPEX           : 1491.90 MUSD
# ✅ Total OPEX            : 11.36 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 269,500.0000
# P_ref                    : 59.0000
# t_TES_hours              : 8.5000
# PPA                      : 84.5077
# CF_hybrid                : 0.5136
# CF_pb                    : 0.2887
# LCOE                     : 231.2371
# Annual_Revenue           : 57,696,567.6622
# PV_to_Grid_MWh           : 300,685.5273
# CSP_to_Grid_MWh          : 149,207.3291
# ✅ Total CAPEX           : 995.69 MUSD
# ✅ Total OPEX            : 7.56 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 86,500.0000
# P_ref                    : 148.0000
# t_TES_hours              : 14.5000
# PPA                      : 274.7909
# CF_hybrid                : 0.1225
# CF_pb                    : 0.0181
# LCOE                     : 646.7545
# Annual_Revenue           : 38,482,968.4294
# PV_to_Grid_MWh           : 83,840.2410
# CSP_to_Grid_MWh          : 23,475.4165
# ✅ Total CAPEX           : 908.15 MUSD
# ✅ Total OPEX            : 6.88 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 147,500.0000
# P_ref                    : 69.0000
# t_TES_hours              : 15.5000
# PPA                      : 56.7311
# CF_hybrid                : 0.4517
# CF_pb                    : 0.2625
# LCOE                     : 159.9335
# Annual_Revenue           : 35,081,856.9719
# PV_to_Grid_MWh           : 237,024.3959
# CSP_to_Grid_MWh          : 158,684.2529
# ✅ Total CAPEX           : 1329.44 MUSD
# ✅ Total OPEX            : 12.97 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 207,500.0000
# P_ref                    : 170.0000
# t_TES_hours              : 6.0000
# PPA                      : 60.2451
# CF_hybrid                : 0.6393
# CF_pb                    : 0.1897
# LCOE                     : 170.6181
# Annual_Revenue           : 54,262,393.4977
# PV_to_Grid_MWh           : 277,518.6072
# CSP_to_Grid_MWh          : 282,515.4874
# ✅ Total CAPEX           : 922.89 MUSD
# ✅ Total OPEX            : 7.57 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 84,000.0000
# P_ref                    : 150.0000
# t_TES_hours              : 5.5000
# PPA                      : 265.9852
# CF_hybrid                : 0.1193
# CF_pb                    : 0.0174
# LCOE                     : 621.0184
# Annual_Revenue           : 36,232,970.3199
# PV_to_Grid_MWh           : 81,617.6748
# CSP_to_Grid_MWh          : 22,881.5068
# ✅ Total CAPEX           : 1722.42 MUSD
# ✅ Total OPEX            : 15.44 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 235,000.0000
# P_ref                    : 197.0000
# t_TES_hours              : 10.5000
# PPA                      : 67.7879
# CF_hybrid                : 0.7530
# CF_pb                    : 0.2145
# LCOE                     : 185.5899
# Annual_Revenue           : 68,931,857.5493
# PV_to_Grid_MWh           : 289,554.2347
# CSP_to_Grid_MWh          : 370,107.2450
# ✅ Total CAPEX           : 1401.10 MUSD
# ✅ Total OPEX            : 9.64 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 248,000.0000
# P_ref                    : 54.0000
# t_TES_hours              : 8.5000
# PPA                      : 119.0298
# CF_hybrid                : 0.3515
# CF_pb                    : 0.1433
# LCOE                     : 313.9712
# Annual_Revenue           : 53,155,950.2646
# PV_to_Grid_MWh           : 240,114.5570
# CSP_to_Grid_MWh          : 67,783.4625
# ✅ Total CAPEX           : 1034.93 MUSD
# ✅ Total OPEX            : 8.02 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 178,500.0000
# P_ref                    : 71.0000
# t_TES_hours              : 8.0000
# PPA                      : 60.3628
# CF_hybrid                : 0.4883
# CF_pb                    : 0.2672
# LCOE                     : 169.0353
# Annual_Revenue           : 40,167,574.9737
# PV_to_Grid_MWh           : 261,576.8917
# CSP_to_Grid_MWh          : 166,204.8525
# ✅ Total CAPEX           : 1179.53 MUSD
# ✅ Total OPEX            : 11.46 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 142,500.0000
# P_ref                    : 184.0000
# t_TES_hours              : 5.5000
# PPA                      : 54.4082
# CF_hybrid                : 0.6207
# CF_pb                    : 0.1935
# LCOE                     : 155.8295
# Annual_Revenue           : 48,093,865.1138
# PV_to_Grid_MWh           : 231,901.2559
# CSP_to_Grid_MWh          : 311,818.0725
# ✅ Total CAPEX           : 1006.42 MUSD
# ✅ Total OPEX            : 8.30 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 176,500.0000
# P_ref                    : 80.0000
# t_TES_hours              : 5.0000
# PPA                      : 62.8911
# CF_hybrid                : 0.4608
# CF_pb                    : 0.2046
# LCOE                     : 175.4210
# Annual_Revenue           : 39,558,506.3657
# PV_to_Grid_MWh           : 260,322.2184
# CSP_to_Grid_MWh          : 143,367.9297
# ✅ Total CAPEX           : 1503.12 MUSD
# ✅ Total OPEX            : 12.15 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 284,500.0000
# P_ref                    : 62.0000
# t_TES_hours              : 3.0000
# PPA                      : 124.9208
# CF_hybrid                : 0.3661
# CF_pb                    : 0.1278
# LCOE                     : 329.0415
# Annual_Revenue           : 58,830,257.2131
# PV_to_Grid_MWh           : 251,278.1074
# CSP_to_Grid_MWh          : 69,392.5446
# ✅ Total CAPEX           : 2048.66 MUSD
# ✅ Total OPEX            : 17.99 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 299,000.0000
# P_ref                    : 184.0000
# t_TES_hours              : 3.0000
# PPA                      : 106.7076
# CF_hybrid                : 0.5349
# CF_pb                    : 0.0994
# LCOE                     : 309.9584
# Annual_Revenue           : 81,621,622.8370
# PV_to_Grid_MWh           : 308,469.3335
# CSP_to_Grid_MWh          : 160,137.7274
# ✅ Total CAPEX           : 1567.02 MUSD
# ✅ Total OPEX            : 15.33 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 235,000.0000
# P_ref                    : 197.0000
# t_TES_hours              : 3.5000
# PPA                      : 76.0198
# CF_hybrid                : 0.5811
# CF_pb                    : 0.1272
# LCOE                     : 221.3381
# Annual_Revenue           : 64,000,005.5885
# PV_to_Grid_MWh           : 289,554.2347
# CSP_to_Grid_MWh          : 219,478.9643
# ✅ Total CAPEX           : 1350.59 MUSD
# ✅ Total OPEX            : 11.15 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 220,000.0000
# P_ref                    : 106.0000
# t_TES_hours              : 11.0000
# PPA                      : 60.6036
# CF_hybrid                : 0.6244
# CF_pb                    : 0.2839
# LCOE                     : 173.7624
# Annual_Revenue           : 53,100,035.5584
# PV_to_Grid_MWh           : 283,328.4229
# CSP_to_Grid_MWh          : 263,662.7832
# ✅ Total CAPEX           : 1020.45 MUSD
# ✅ Total OPEX            : 8.44 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 176,500.0000
# P_ref                    : 83.0000
# t_TES_hours              : 5.0000
# PPA                      : 62.7092
# CF_hybrid                : 0.4663
# CF_pb                    : 0.2038
# LCOE                     : 175.8189
# Annual_Revenue           : 40,132,688.3100
# PV_to_Grid_MWh           : 260,322.2184
# CSP_to_Grid_MWh          : 148,198.2936
# ✅ Total CAPEX           : 440.35 MUSD
# ✅ Total OPEX            : 4.10 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 63,000.0000
# P_ref                    : 60.0000
# t_TES_hours              : 6.5000
# PPA                      : 50.7117
# CF_hybrid                : 0.2462
# CF_pb                    : 0.2086
# LCOE                     : 145.8278
# Annual_Revenue           : 17,778,863.9508
# PV_to_Grid_MWh           : 106,047.9217
# CSP_to_Grid_MWh          : 109,653.7742
# ✅ Total CAPEX           : 630.49 MUSD
# ✅ Total OPEX            : 5.11 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 65,500.0000
# P_ref                    : 77.0000
# t_TES_hours              : 13.0000
# PPA                      : 50.3019
# CF_hybrid                : 0.3217
# CF_pb                    : 0.2543
# LCOE                     : 157.0916
# Annual_Revenue           : 24,690,165.8963
# PV_to_Grid_MWh           : 110,290.3275
# CSP_to_Grid_MWh          : 171,532.0636
# ✅ Total CAPEX           : 1613.29 MUSD
# ✅ Total OPEX            : 12.03 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 258,500.0000
# P_ref                    : 103.0000
# t_TES_hours              : 1.0000
# PPA                      : 209.9230
# CF_hybrid                : 0.2368
# CF_pb                    : 0.0410
# LCOE                     : 540.9991
# Annual_Revenue           : 62,139,321.9331
# PV_to_Grid_MWh           : 170,500.8944
# CSP_to_Grid_MWh          : 36,975.5739
# ✅ Total CAPEX           : 1237.56 MUSD
# ✅ Total OPEX            : 10.44 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 227,500.0000
# P_ref                    : 85.0000
# t_TES_hours              : 7.5000
# PPA                      : 65.9735
# CF_hybrid                : 0.5317
# CF_pb                    : 0.2407
# LCOE                     : 187.4601
# Annual_Revenue           : 48,873,620.6710
# PV_to_Grid_MWh           : 286,546.2289
# CSP_to_Grid_MWh          : 179,203.5479
# ✅ Total CAPEX           : 1717.30 MUSD
# ✅ Total OPEX            : 13.78 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 252,000.0000
# P_ref                    : 161.0000
# t_TES_hours              : 5.5000
# PPA                      : 145.0037
# CF_hybrid                : 0.3570
# CF_pb                    : 0.0489
# LCOE                     : 385.1390
# Annual_Revenue           : 67,111,227.3647
# PV_to_Grid_MWh           : 243,789.4687
# CSP_to_Grid_MWh          : 68,946.5048
# ✅ Total CAPEX           : 1514.55 MUSD
# ✅ Total OPEX            : 11.90 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 237,500.0000
# P_ref                    : 104.0000
# t_TES_hours              : 5.5000
# PPA                      : 76.7183
# CF_hybrid                : 0.5353
# CF_pb                    : 0.1959
# LCOE                     : 225.9835
# Annual_Revenue           : 58,939,917.2562
# PV_to_Grid_MWh           : 290,512.4555
# CSP_to_Grid_MWh          : 178,453.6123
# ✅ Total CAPEX           : 936.06 MUSD
# ✅ Total OPEX            : 9.25 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 51,500.0000
# P_ref                    : 187.0000
# t_TES_hours              : 9.0000
# PPA                      : 51.7719
# CF_hybrid                : 0.4756
# CF_pb                    : 0.2014
# LCOE                     : 161.7552
# Annual_Revenue           : 38,323,207.3748
# PV_to_Grid_MWh           : 86,810.6620
# CSP_to_Grid_MWh          : 329,838.8862
# ✅ Total CAPEX           : 1515.08 MUSD
# ✅ Total OPEX            : 11.91 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 282,500.0000
# P_ref                    : 59.0000
# t_TES_hours              : 8.5000
# PPA                      : 86.3314
# CF_hybrid                : 0.5135
# CF_pb                    : 0.2817
# LCOE                     : 235.7003
# Annual_Revenue           : 58,968,791.7164
# PV_to_Grid_MWh           : 304,225.5144
# CSP_to_Grid_MWh          : 145,599.9710
# ✅ Total CAPEX           : 589.11 MUSD
# ✅ Total OPEX            : 5.12 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 68,500.0000
# P_ref                    : 77.0000
# t_TES_hours              : 9.0000
# PPA                      : 48.2554
# CF_hybrid                : 0.3236
# CF_pb                    : 0.2493
# LCOE                     : 147.1432
# Annual_Revenue           : 23,418,451.6742
# PV_to_Grid_MWh           : 115,341.6007
# CSP_to_Grid_MWh          : 168,157.6249
# ✅ Total CAPEX           : 811.98 MUSD
# ✅ Total OPEX            : 7.43 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 83,500.0000
# P_ref                    : 121.0000
# t_TES_hours              : 4.0000
# PPA                      : 50.2516
# CF_hybrid                : 0.4461
# CF_pb                    : 0.2360
# LCOE                     : 148.0840
# Annual_Revenue           : 32,645,656.1659
# PV_to_Grid_MWh           : 140,597.8388
# CSP_to_Grid_MWh          : 250,153.8735
# ✅ Total CAPEX           : 623.75 MUSD
# ✅ Total OPEX            : 6.54 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 63,500.0000
# P_ref                    : 115.0000
# t_TES_hours              : 6.5000
# PPA                      : 42.9985
# CF_hybrid                : 0.3805
# CF_pb                    : 0.2246
# LCOE                     : 135.8656
# Annual_Revenue           : 25,912,607.7853
# PV_to_Grid_MWh           : 107,028.0848
# CSP_to_Grid_MWh          : 226,279.0668
# ✅ Total CAPEX           : 1584.72 MUSD
# ✅ Total OPEX            : 12.67 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 294,500.0000
# P_ref                    : 65.0000
# t_TES_hours              : 12.0000
# PPA                      : 89.1905
# CF_hybrid                : 0.5198
# CF_pb                    : 0.2599
# LCOE                     : 244.0199
# Annual_Revenue           : 61,884,830.8683
# PV_to_Grid_MWh           : 307,340.6641
# CSP_to_Grid_MWh          : 147,961.4454
# ✅ Total CAPEX           : 1543.80 MUSD
# ✅ Total OPEX            : 13.46 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 209,000.0000
# P_ref                    : 174.0000
# t_TES_hours              : 12.5000
# PPA                      : 62.1432
# CF_hybrid                : 0.7223
# CF_pb                    : 0.2326
# LCOE                     : 172.8151
# Annual_Revenue           : 61,405,489.1197
# PV_to_Grid_MWh           : 278,249.5239
# CSP_to_Grid_MWh          : 354,522.8253
# ✅ Total CAPEX           : 773.91 MUSD
# ✅ Total OPEX            : 7.61 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 127,500.0000
# P_ref                    : 106.0000
# t_TES_hours              : 6.0000
# PPA                      : 48.1212
# CF_hybrid                : 0.4561
# CF_pb                    : 0.2006
# LCOE                     : 139.3487
# Annual_Revenue           : 31,642,866.3365
# PV_to_Grid_MWh           : 213,291.1754
# CSP_to_Grid_MWh          : 186,273.4492
# ✅ Total CAPEX           : 986.86 MUSD
# ✅ Total OPEX            : 8.10 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 171,500.0000
# P_ref                    : 79.0000
# t_TES_hours              : 6.0000
# PPA                      : 59.1851
# CF_hybrid                : 0.4742
# CF_pb                    : 0.2288
# LCOE                     : 167.0885
# Annual_Revenue           : 38,752,862.0041
# PV_to_Grid_MWh           : 257,020.7914
# CSP_to_Grid_MWh          : 158,344.3609
# ✅ Total CAPEX           : 1093.28 MUSD
# ✅ Total OPEX            : 10.97 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 176,500.0000
# P_ref                    : 151.0000
# t_TES_hours              : 5.0000
# PPA                      : 56.7413
# CF_hybrid                : 0.5506
# CF_pb                    : 0.1678
# LCOE                     : 163.5484
# Annual_Revenue           : 44,922,978.2736
# PV_to_Grid_MWh           : 260,322.2184
# CSP_to_Grid_MWh          : 221,969.3498
# ✅ Total CAPEX           : 1801.74 MUSD
# ✅ Total OPEX            : 14.49 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 264,000.0000
# P_ref                    : 165.0000
# t_TES_hours              : 5.5000
# PPA                      : 145.0174
# CF_hybrid                : 0.3735
# CF_pb                    : 0.0501
# LCOE                     : 386.3543
# Annual_Revenue           : 70,451,289.2780
# PV_to_Grid_MWh           : 254,704.2076
# CSP_to_Grid_MWh          : 72,481.6820
# ✅ Total CAPEX           : 1207.82 MUSD
# ✅ Total OPEX            : 11.97 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 146,500.0000
# P_ref                    : 198.0000
# t_TES_hours              : 4.0000
# PPA                      : 63.2560
# CF_hybrid                : 0.5387
# CF_pb                    : 0.1360
# LCOE                     : 184.3538
# Annual_Revenue           : 49,486,788.2330
# PV_to_Grid_MWh           : 236,035.8590
# CSP_to_Grid_MWh          : 235,878.2633
# ✅ Total CAPEX           : 1468.53 MUSD
# ✅ Total OPEX            : 11.80 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 265,000.0000
# P_ref                    : 74.0000
# t_TES_hours              : 6.0000
# PPA                      : 83.4509
# CF_hybrid                : 0.5014
# CF_pb                    : 0.2158
# LCOE                     : 234.5195
# Annual_Revenue           : 57,406,083.5041
# PV_to_Grid_MWh           : 299,401.9422
# CSP_to_Grid_MWh          : 139,859.6142
# ✅ Total CAPEX           : 1030.41 MUSD
# ✅ Total OPEX            : 8.12 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 127,000.0000
# P_ref                    : 110.0000
# t_TES_hours              : 12.5000
# PPA                      : 52.2137
# CF_hybrid                : 0.5218
# CF_pb                    : 0.2537
# LCOE                     : 157.7977
# Annual_Revenue           : 40,125,009.4438
# PV_to_Grid_MWh           : 212,582.1189
# CSP_to_Grid_MWh          : 244,504.7901
# ✅ Total CAPEX           : 1254.80 MUSD
# ✅ Total OPEX            : 11.00 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 171,500.0000
# P_ref                    : 148.0000
# t_TES_hours              : 6.0000
# PPA                      : 60.2160
# CF_hybrid                : 0.5790
# CF_pb                    : 0.1930
# LCOE                     : 175.3542
# Annual_Revenue           : 49,971,948.0425
# PV_to_Grid_MWh           : 257,020.7914
# CSP_to_Grid_MWh          : 250,201.3423
# ✅ Total CAPEX           : 903.63 MUSD
# ✅ Total OPEX            : 7.84 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 178,500.0000
# P_ref                    : 73.0000
# t_TES_hours              : 8.0000
# PPA                      : 58.5126
# CF_hybrid                : 0.4554
# CF_pb                    : 0.2148
# LCOE                     : 160.3409
# Annual_Revenue           : 35,902,618.6938
# PV_to_Grid_MWh           : 261,576.8917
# CSP_to_Grid_MWh          : 137,369.9897
# ✅ Total CAPEX           : 1257.12 MUSD
# ✅ Total OPEX            : 11.94 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 143,500.0000
# P_ref                    : 197.0000
# t_TES_hours              : 10.5000
# PPA                      : 53.7728
# CF_hybrid                : 0.6842
# CF_pb                    : 0.2123
# LCOE                     : 150.2152
# Annual_Revenue           : 50,984,744.8660
# PV_to_Grid_MWh           : 232,962.6168
# CSP_to_Grid_MWh          : 366,365.1743
# ✅ Total CAPEX           : 1375.50 MUSD
# ✅ Total OPEX            : 10.39 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 239,000.0000
# P_ref                    : 69.0000
# t_TES_hours              : 15.5000
# PPA                      : 71.5217
# CF_hybrid                : 0.5563
# CF_pb                    : 0.3246
# LCOE                     : 196.6605
# Annual_Revenue           : 53,107,994.9626
# PV_to_Grid_MWh           : 291,060.7062
# CSP_to_Grid_MWh          : 196,215.8851
# ✅ Total CAPEX           : 1325.78 MUSD
# ✅ Total OPEX            : 10.32 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 242,500.0000
# P_ref                    : 65.0000
# t_TES_hours              : 8.5000
# PPA                      : 74.3206
# CF_hybrid                : 0.5159
# CF_pb                    : 0.2804
# LCOE                     : 205.0449
# Annual_Revenue           : 51,498,378.1930
# PV_to_Grid_MWh           : 292,307.3678
# CSP_to_Grid_MWh          : 159,663.6436
# ✅ Total CAPEX           : 1642.48 MUSD
# ✅ Total OPEX            : 14.65 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 233,500.0000
# P_ref                    : 183.0000
# t_TES_hours              : 5.5000
# PPA                      : 75.8556
# CF_hybrid                : 0.6152
# CF_pb                    : 0.1559
# LCOE                     : 216.4887
# Annual_Revenue           : 65,662,517.4812
# PV_to_Grid_MWh           : 288,975.6495
# CSP_to_Grid_MWh          : 249,964.7043
# ✅ Total CAPEX           : 918.95 MUSD
# ✅ Total OPEX            : 8.17 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 146,500.0000
# P_ref                    : 101.0000
# t_TES_hours              : 5.5000
# PPA                      : 52.1434
# CF_hybrid                : 0.4887
# CF_pb                    : 0.2171
# LCOE                     : 152.4206
# Annual_Revenue           : 36,711,304.2779
# PV_to_Grid_MWh           : 236,035.8590
# CSP_to_Grid_MWh          : 192,067.8777
# ✅ Total CAPEX           : 957.54 MUSD
# ✅ Total OPEX            : 7.92 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 176,500.0000
# P_ref                    : 73.0000
# t_TES_hours              : 9.0000
# PPA                      : 56.5459
# CF_hybrid                : 0.4893
# CF_pb                    : 0.2632
# LCOE                     : 157.2419
# Annual_Revenue           : 37,660,462.3402
# PV_to_Grid_MWh           : 260,322.2184
# CSP_to_Grid_MWh          : 168,315.0683
# ✅ Total CAPEX           : 937.69 MUSD
# ✅ Total OPEX            : 9.29 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 58,000.0000
# P_ref                    : 185.0000
# t_TES_hours              : 8.0000
# PPA                      : 51.4587
# CF_hybrid                : 0.4861
# CF_pb                    : 0.2024
# LCOE                     : 158.6034
# Annual_Revenue           : 38,415,330.1872
# PV_to_Grid_MWh           : 97,744.1817
# CSP_to_Grid_MWh          : 328,084.7829
# Gen   1/20 | min PPA: 42.999 USD/MWh | best CF: 0.7530
# ✅ Total CAPEX           : 532.81 MUSD
# ✅ Total OPEX            : 4.29 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 54,500.0000
# P_ref                    : 63.0000
# t_TES_hours              : 6.5000
# PPA                      : 52.9926
# CF_hybrid                : 0.2668
# CF_pb                    : 0.2571
# LCOE                     : 159.9390
# Annual_Revenue           : 20,836,172.4466
# PV_to_Grid_MWh           : 91,865.4137
# CSP_to_Grid_MWh          : 141,874.4576
# ✅ Total CAPEX           : 1362.79 MUSD
# ✅ Total OPEX            : 11.06 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 251,000.0000
# P_ref                    : 76.0000
# t_TES_hours              : 15.5000
# PPA                      : 71.0449
# CF_hybrid                : 0.5527
# CF_pb                    : 0.2839
# LCOE                     : 197.6670
# Annual_Revenue           : 53,380,956.6438
# PV_to_Grid_MWh           : 295,155.6725
# CSP_to_Grid_MWh          : 189,023.6128
# ✅ Total CAPEX           : 839.99 MUSD
# ✅ Total OPEX            : 7.04 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 68,500.0000
# P_ref                    : 119.0000
# t_TES_hours              : 9.0000
# PPA                      : 49.4680
# CF_hybrid                : 0.4249
# CF_pb                    : 0.2464
# LCOE                     : 159.0991
# Annual_Revenue           : 33,131,392.2602
# PV_to_Grid_MWh           : 115,341.6007
# CSP_to_Grid_MWh          : 256,878.2411
# ✅ Total CAPEX           : 906.92 MUSD
# ✅ Total OPEX            : 9.37 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 51,000.0000
# P_ref                    : 187.0000
# t_TES_hours              : 7.0000
# PPA                      : 46.3793
# CF_hybrid                : 0.5374
# CF_pb                    : 0.2350
# LCOE                     : 139.5718
# Annual_Revenue           : 37,533,434.4488
# PV_to_Grid_MWh           : 85,843.7530
# CSP_to_Grid_MWh          : 384,885.0813
# ✅ Total CAPEX           : 840.22 MUSD
# ✅ Total OPEX            : 9.35 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 55,500.0000
# P_ref                    : 187.0000
# t_TES_hours              : 6.5000
# PPA                      : 43.9174
# CF_hybrid                : 0.5363
# CF_pb                    : 0.2297
# LCOE                     : 130.9883
# Annual_Revenue           : 35,447,953.4062
# PV_to_Grid_MWh           : 93,524.4204
# CSP_to_Grid_MWh          : 376,315.7108
# ✅ Total CAPEX           : 737.05 MUSD
# ✅ Total OPEX            : 6.72 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 63,500.0000
# P_ref                    : 115.0000
# t_TES_hours              : 9.0000
# PPA                      : 45.0090
# CF_hybrid                : 0.4122
# CF_pb                    : 0.2522
# LCOE                     : 145.3993
# Annual_Revenue           : 29,615,645.2707
# PV_to_Grid_MWh           : 107,028.0848
# CSP_to_Grid_MWh          : 254,093.8603
# ✅ Total CAPEX           : 719.52 MUSD
# ✅ Total OPEX            : 7.32 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 85,000.0000
# P_ref                    : 121.0000
# t_TES_hours              : 4.0000
# PPA                      : 47.0084
# CF_hybrid                : 0.4341
# CF_pb                    : 0.2236
# LCOE                     : 136.7988
# Annual_Revenue           : 29,667,971.1729
# PV_to_Grid_MWh           : 143,209.7077
# CSP_to_Grid_MWh          : 237,018.2510
# ✅ Total CAPEX           : 1199.40 MUSD
# ✅ Total OPEX            : 9.87 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 206,000.0000
# P_ref                    : 90.0000
# t_TES_hours              : 7.5000
# PPA                      : 61.8637
# CF_hybrid                : 0.5410
# CF_pb                    : 0.2500
# LCOE                     : 178.0435
# Annual_Revenue           : 47,120,415.4659
# PV_to_Grid_MWh           : 276,774.1872
# CSP_to_Grid_MWh          : 197,105.8930
# ✅ Total CAPEX           : 1539.56 MUSD
# ✅ Total OPEX            : 13.46 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 209,000.0000
# P_ref                    : 174.0000
# t_TES_hours              : 12.0000
# PPA                      : 62.0850
# CF_hybrid                : 0.7218
# CF_pb                    : 0.2323
# LCOE                     : 172.5361
# Annual_Revenue           : 61,273,851.2196
# PV_to_Grid_MWh           : 278,249.5239
# CSP_to_Grid_MWh          : 354,020.2404
# ✅ Total CAPEX           : 591.45 MUSD
# ✅ Total OPEX            : 5.12 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 68,500.0000
# P_ref                    : 77.0000
# t_TES_hours              : 9.5000
# PPA                      : 48.3327
# CF_hybrid                : 0.3235
# CF_pb                    : 0.2492
# LCOE                     : 147.6916
# Annual_Revenue           : 23,490,985.1442
# PV_to_Grid_MWh           : 115,341.6007
# CSP_to_Grid_MWh          : 168,087.2858
# ✅ Total CAPEX           : 1321.99 MUSD
# ✅ Total OPEX            : 10.94 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 215,500.0000
# P_ref                    : 106.0000
# t_TES_hours              : 11.0000
# PPA                      : 59.6742
# CF_hybrid                : 0.6201
# CF_pb                    : 0.2820
# LCOE                     : 171.3122
# Annual_Revenue           : 51,997,045.2458
# PV_to_Grid_MWh           : 281,316.4743
# CSP_to_Grid_MWh          : 261,875.0803
# ✅ Total CAPEX           : 1404.09 MUSD
# ✅ Total OPEX            : 13.53 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 220,000.0000
# P_ref                    : 170.0000
# t_TES_hours              : 6.0000
# PPA                      : 62.9091
# CF_hybrid                : 0.6457
# CF_pb                    : 0.1896
# LCOE                     : 178.1182
# Annual_Revenue           : 57,141,722.0902
# PV_to_Grid_MWh           : 283,328.4229
# CSP_to_Grid_MWh          : 282,305.9379
# ✅ Total CAPEX           : 1326.44 MUSD
# ✅ Total OPEX            : 12.93 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 207,500.0000
# P_ref                    : 169.0000
# t_TES_hours              : 6.0000
# PPA                      : 60.2537
# CF_hybrid                : 0.6375
# CF_pb                    : 0.1898
# LCOE                     : 170.6954
# Annual_Revenue           : 54,129,177.2547
# PV_to_Grid_MWh           : 277,518.6072
# CSP_to_Grid_MWh          : 280,935.6052
# ✅ Total CAPEX           : 1118.24 MUSD
# ✅ Total OPEX            : 9.97 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 207,500.0000
# P_ref                    : 97.0000
# t_TES_hours              : 7.0000
# PPA                      : 60.3861
# CF_hybrid                : 0.5214
# CF_pb                    : 0.2109
# LCOE                     : 173.9038
# Annual_Revenue           : 44,700,389.5812
# PV_to_Grid_MWh           : 277,518.6072
# CSP_to_Grid_MWh          : 179,231.3367
# ✅ Total CAPEX           : 1048.02 MUSD
# ✅ Total OPEX            : 9.21 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 147,500.0000
# P_ref                    : 122.0000
# t_TES_hours              : 4.0000
# PPA                      : 59.7394
# CF_hybrid                : 0.4889
# CF_pb                    : 0.1789
# LCOE                     : 173.5106
# Annual_Revenue           : 41,756,751.0555
# PV_to_Grid_MWh           : 237,024.3959
# CSP_to_Grid_MWh          : 191,225.7625
# ✅ Total CAPEX           : 697.06 MUSD
# ✅ Total OPEX            : 6.52 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 82,500.0000
# P_ref                    : 102.0000
# t_TES_hours              : 5.5000
# PPA                      : 45.3838
# CF_hybrid                : 0.4135
# CF_pb                    : 0.2499
# LCOE                     : 137.5179
# Annual_Revenue           : 28,166,320.2719
# PV_to_Grid_MWh           : 138,971.9427
# CSP_to_Grid_MWh          : 223,276.6901
# ✅ Total CAPEX           : 1538.16 MUSD
# ✅ Total OPEX            : 14.59 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 215,000.0000
# P_ref                    : 198.0000
# t_TES_hours              : 4.0000
# PPA                      : 72.6168
# CF_hybrid                : 0.5948
# CF_pb                    : 0.1383
# LCOE                     : 211.3739
# Annual_Revenue           : 62,360,671.2484
# PV_to_Grid_MWh           : 281,082.6805
# CSP_to_Grid_MWh          : 239,950.0469
# ✅ Total CAPEX           : 1117.71 MUSD
# ✅ Total OPEX            : 8.83 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 156,000.0000
# P_ref                    : 106.0000
# t_TES_hours              : 11.0000
# PPA                      : 53.9327
# CF_hybrid                : 0.5595
# CF_pb                    : 0.2641
# LCOE                     : 159.6530
# Annual_Revenue           : 43,539,935.1939
# PV_to_Grid_MWh           : 244,878.5431
# CSP_to_Grid_MWh          : 245,269.7660
# ✅ Total CAPEX           : 930.47 MUSD
# ✅ Total OPEX            : 9.58 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 63,000.0000
# P_ref                    : 187.0000
# t_TES_hours              : 6.5000
# PPA                      : 46.6289
# CF_hybrid                : 0.5590
# CF_pb                    : 0.2342
# LCOE                     : 137.6015
# Annual_Revenue           : 38,479,829.0169
# PV_to_Grid_MWh           : 106,047.9217
# CSP_to_Grid_MWh          : 383,614.5597
# ✅ Total CAPEX           : 432.90 MUSD
# ✅ Total OPEX            : 3.97 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 55,500.0000
# P_ref                    : 60.0000
# t_TES_hours              : 9.0000
# PPA                      : 50.8618
# CF_hybrid                : 0.2317
# CF_pb                    : 0.2082
# LCOE                     : 152.0674
# Annual_Revenue           : 17,416,692.9030
# PV_to_Grid_MWh           : 93,524.4204
# CSP_to_Grid_MWh          : 109,421.9171
# ✅ Total CAPEX           : 1366.81 MUSD
# ✅ Total OPEX            : 10.28 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 243,500.0000
# P_ref                    : 63.0000
# t_TES_hours              : 16.0000
# PPA                      : 73.3360
# CF_hybrid                : 0.5447
# CF_pb                    : 0.3343
# LCOE                     : 199.4631
# Annual_Revenue           : 52,729,366.6185
# PV_to_Grid_MWh           : 292,660.0046
# CSP_to_Grid_MWh          : 184,519.1207
# ✅ Total CAPEX           : 459.93 MUSD
# ✅ Total OPEX            : 4.45 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 59,500.0000
# P_ref                    : 69.0000
# t_TES_hours              : 6.0000
# PPA                      : 49.1633
# CF_hybrid                : 0.2627
# CF_pb                    : 0.2149
# LCOE                     : 143.5069
# Annual_Revenue           : 18,737,499.8810
# PV_to_Grid_MWh           : 100,199.8352
# CSP_to_Grid_MWh          : 129,906.5000
# ✅ Total CAPEX           : 833.42 MUSD
# ✅ Total OPEX            : 8.05 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 142,500.0000
# P_ref                    : 106.0000
# t_TES_hours              : 6.0000
# PPA                      : 49.9254
# CF_hybrid                : 0.4738
# CF_pb                    : 0.1972
# LCOE                     : 144.1306
# Annual_Revenue           : 33,938,155.5906
# PV_to_Grid_MWh           : 231,901.2559
# CSP_to_Grid_MWh          : 183,155.1600
# ✅ Total CAPEX           : 1120.02 MUSD
# ✅ Total OPEX            : 11.01 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 127,500.0000
# P_ref                    : 184.0000
# t_TES_hours              : 5.5000
# PPA                      : 52.4600
# CF_hybrid                : 0.6096
# CF_pb                    : 0.1990
# LCOE                     : 150.9107
# Annual_Revenue           : 45,798,575.8597
# PV_to_Grid_MWh           : 213,291.1754
# CSP_to_Grid_MWh          : 320,693.5118
# ✅ Total CAPEX           : 925.03 MUSD
# ✅ Total OPEX            : 8.01 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 129,000.0000
# P_ref                    : 109.0000
# t_TES_hours              : 10.5000
# PPA                      : 48.2018
# CF_hybrid                : 0.5194
# CF_pb                    : 0.2510
# LCOE                     : 143.8757
# Annual_Revenue           : 36,738,360.4882
# PV_to_Grid_MWh           : 215,394.9376
# CSP_to_Grid_MWh          : 239,634.6326
# ✅ Total CAPEX           : 1281.97 MUSD
# ✅ Total OPEX            : 11.82 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 143,500.0000
# P_ref                    : 197.0000
# t_TES_hours              : 12.5000
# PPA                      : 57.5635
# CF_hybrid                : 0.6412
# CF_pb                    : 0.1905
# LCOE                     : 162.8035
# Annual_Revenue           : 51,633,173.6178
# PV_to_Grid_MWh           : 232,962.6168
# CSP_to_Grid_MWh          : 328,748.0048
# ✅ Total CAPEX           : 985.76 MUSD
# ✅ Total OPEX            : 9.86 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 63,000.0000
# P_ref                    : 195.0000
# t_TES_hours              : 10.5000
# PPA                      : 47.9332
# CF_hybrid                : 0.5633
# CF_pb                    : 0.2268
# LCOE                     : 144.0624
# Annual_Revenue           : 40,476,177.7104
# PV_to_Grid_MWh           : 106,047.9217
# CSP_to_Grid_MWh          : 387,431.9476
# ✅ Total CAPEX           : 1176.48 MUSD
# ✅ Total OPEX            : 9.65 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 235,000.0000
# ...
# ✅ Total OPEX            : 15.94 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 243,500.0000
# P_ref                    : 200.0000
# t_TES_hours              : 12.5000
# PPA                      : 68.0658
# CF_hybrid                : 0.7796
# CF_pb                    : 0.2228
# LCOE                     : 185.9437
# Annual_Revenue           : 71,466,722.2900
# PV_to_Grid_MWh           : 292,660.0046
# CSP_to_Grid_MWh          : 390,304.3911
# ✅ Total CAPEX           : 1198.14 MUSD
# ✅ Total OPEX            : 11.67 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 129,500.0000
# P_ref                    : 200.0000
# t_TES_hours              : 12.0000
# PPA                      : 50.7195
# CF_hybrid                : 0.6897
# CF_pb                    : 0.2215
# LCOE                     : 142.4918
# Annual_Revenue           : 48,879,091.9733
# PV_to_Grid_MWh           : 216,097.1500
# CSP_to_Grid_MWh          : 388,083.1646
# ✅ Total CAPEX           : 959.19 MUSD
# ✅ Total OPEX            : 10.43 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 84,000.0000
# P_ref                    : 200.0000
# t_TES_hours              : 6.5000
# PPA                      : 45.8279
# CF_hybrid                : 0.6121
# CF_pb                    : 0.2254
# LCOE                     : 130.5676
# Annual_Revenue           : 40,223,368.3488
# PV_to_Grid_MWh           : 141,393.2349
# CSP_to_Grid_MWh          : 394,833.0926
# ✅ Total CAPEX           : 1633.34 MUSD
# ✅ Total OPEX            : 14.89 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 221,000.0000
# P_ref                    : 199.0000
# t_TES_hours              : 12.5000
# PPA                      : 63.4627
# CF_hybrid                : 0.7635
# CF_pb                    : 0.2209
# LCOE                     : 173.9679
# Annual_Revenue           : 65,619,585.8821
# PV_to_Grid_MWh           : 283,769.9798
# CSP_to_Grid_MWh          : 385,018.3033
# ✅ Total CAPEX           : 701.12 MUSD
# ✅ Total OPEX            : 7.55 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 51,000.0000
# P_ref                    : 144.0000
# t_TES_hours              : 6.5000
# PPA                      : 42.6119
# CF_hybrid                : 0.4345
# CF_pb                    : 0.2337
# LCOE                     : 134.2473
# Annual_Revenue           : 29,328,014.9822
# PV_to_Grid_MWh           : 85,843.7530
# CSP_to_Grid_MWh          : 294,821.2667
# ✅ Total CAPEX           : 712.67 MUSD
# ✅ Total OPEX            : 7.37 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 85,500.0000
# P_ref                    : 124.0000
# t_TES_hours              : 6.5000
# PPA                      : 43.6040
# CF_hybrid                : 0.4441
# CF_pb                    : 0.2256
# LCOE                     : 132.7342
# Annual_Revenue           : 29,503,504.2193
# PV_to_Grid_MWh           : 144,024.1035
# CSP_to_Grid_MWh          : 245,005.2651
# ✅ Total CAPEX           : 1154.51 MUSD
# ✅ Total OPEX            : 11.30 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 131,500.0000
# P_ref                    : 190.0000
# t_TES_hours              : 11.0000
# PPA                      : 49.8686
# CF_hybrid                : 0.6755
# CF_pb                    : 0.2241
# LCOE                     : 140.2841
# Annual_Revenue           : 47,157,714.2007
# PV_to_Grid_MWh           : 218,776.1763
# CSP_to_Grid_MWh          : 372,983.5549
# ✅ Total CAPEX           : 1020.37 MUSD
# ✅ Total OPEX            : 10.70 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 94,500.0000
# P_ref                    : 199.0000
# t_TES_hours              : 7.0000
# PPA                      : 46.9868
# CF_hybrid                : 0.6352
# CF_pb                    : 0.2279
# LCOE                     : 133.1220
# Annual_Revenue           : 42,386,182.3155
# PV_to_Grid_MWh           : 159,180.1678
# CSP_to_Grid_MWh          : 397,276.9450
# ✅ Total CAPEX           : 1558.48 MUSD
# ✅ Total OPEX            : 14.25 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 210,000.0000
# P_ref                    : 195.0000
# t_TES_hours              : 13.0000
# PPA                      : 61.2099
# CF_hybrid                : 0.7523
# CF_pb                    : 0.2226
# LCOE                     : 168.5263
# Annual_Revenue           : 62,655,328.9595
# PV_to_Grid_MWh           : 278,736.4924
# CSP_to_Grid_MWh          : 380,260.2771
# ✅ Total CAPEX           : 1555.15 MUSD
# ✅ Total OPEX            : 14.45 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 211,500.0000
# P_ref                    : 199.0000
# t_TES_hours              : 12.5000
# PPA                      : 61.3985
# CF_hybrid                : 0.7516
# CF_pb                    : 0.2174
# LCOE                     : 168.6553
# Annual_Revenue           : 62,746,763.7042
# PV_to_Grid_MWh           : 279,448.6651
# CSP_to_Grid_MWh          : 378,973.2122
# ✅ Total CAPEX           : 983.71 MUSD
# ✅ Total OPEX            : 10.51 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 96,000.0000
# P_ref                    : 195.0000
# t_TES_hours              : 7.0000
# PPA                      : 46.2814
# CF_hybrid                : 0.6223
# CF_pb                    : 0.2245
# LCOE                     : 131.3610
# Annual_Revenue           : 41,059,089.3610
# PV_to_Grid_MWh           : 161,585.4216
# CSP_to_Grid_MWh          : 383,562.0832
# ✅ Total CAPEX           : 1851.21 MUSD
# ✅ Total OPEX            : 16.53 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 257,000.0000
# P_ref                    : 199.0000
# t_TES_hours              : 12.5000
# PPA                      : 70.2838
# CF_hybrid                : 0.7832
# CF_pb                    : 0.2232
# LCOE                     : 191.6970
# Annual_Revenue           : 74,023,234.1555
# PV_to_Grid_MWh           : 297,036.6526
# CSP_to_Grid_MWh          : 389,035.7002
# ✅ Total CAPEX           : 1541.73 MUSD
# ✅ Total OPEX            : 14.31 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 208,000.0000
# P_ref                    : 199.0000
# t_TES_hours              : 13.0000
# PPA                      : 60.8895
# CF_hybrid                : 0.7498
# CF_pb                    : 0.2175
# LCOE                     : 167.5839
# Annual_Revenue           : 62,194,215.5445
# PV_to_Grid_MWh           : 277,755.9205
# CSP_to_Grid_MWh          : 379,092.7140
# ✅ Total CAPEX           : 1306.03 MUSD
# ✅ Total OPEX            : 12.46 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 154,500.0000
# P_ref                    : 200.0000
# t_TES_hours              : 10.5000
# PPA                      : 53.8127
# CF_hybrid                : 0.7172
# CF_pb                    : 0.2196
# LCOE                     : 148.9611
# Annual_Revenue           : 53,027,460.1526
# PV_to_Grid_MWh           : 243,559.8435
# CSP_to_Grid_MWh          : 384,724.9643
# ✅ Total CAPEX           : 1837.40 MUSD
# ✅ Total OPEX            : 16.42 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 263,500.0000
# P_ref                    : 190.0000
# t_TES_hours              : 13.0000
# PPA                      : 70.5012
# CF_hybrid                : 0.7725
# CF_pb                    : 0.2270
# LCOE                     : 192.9161
# Annual_Revenue           : 73,486,069.0172
# PV_to_Grid_MWh           : 298,971.1836
# CSP_to_Grid_MWh          : 377,756.7823
# ✅ Total CAPEX           : 637.85 MUSD
# ✅ Total OPEX            : 6.75 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 52,500.0000
# P_ref                    : 124.0000
# t_TES_hours              : 6.5000
# PPA                      : 42.5474
# CF_hybrid                : 0.3886
# CF_pb                    : 0.2319
# LCOE                     : 136.2089
# Annual_Revenue           : 26,557,451.7433
# PV_to_Grid_MWh           : 88,471.4238
# CSP_to_Grid_MWh          : 251,944.0826
# ✅ Total CAPEX           : 1839.28 MUSD
# ✅ Total OPEX            : 16.56 MUSD/year
#
# --- Hybrid System Summary ---
# desired_array_size       : 258,500.0000
# P_ref                    : 200.0000
# t_TES_hours              : 13.0000
# PPA                      : 70.0888
# CF_hybrid                : 0.7807
# CF_pb                    : 0.2206
# LCOE                     : 191.2637
# Annual_Revenue           : 73,682,899.4620
# PV_to_Grid_MWh           : 297,495.4097
# CSP_to_Grid_MWh          : 386,414.6758
# Gen  20/20 | min PPA: 42.503 USD/MWh | best CF: 0.7833
#
# === Pareto front (PPA, CF) ===
# das=50500 kWdc | P_ref=124.0 MWe | TES=6.5 h | SM=1.5 | PPA=42.50 USD/MWh | CF=0.3847
# das=53000 kWdc | P_ref=124.0 MWe | TES=6.5 h | SM=1.5 | PPA=42.54 USD/MWh | CF=0.3895
# das=51000 kWdc | P_ref=144.0 MWe | TES=6.5 h | SM=1.5 | PPA=42.61 USD/MWh | CF=0.4345
# das=86000 kWdc | P_ref=144.0 MWe | TES=6.5 h | SM=1.4 | PPA=43.53 USD/MWh | CF=0.4925
# das=86000 kWdc | P_ref=144.0 MWe | TES=6.5 h | SM=1.6 | PPA=43.77 USD/MWh | CF=0.5074
# das=62500 kWdc | P_ref=182.0 MWe | TES=6.5 h | SM=1.4 | PPA=43.84 USD/MWh | CF=0.5377
# das=57500 kWdc | P_ref=187.0 MWe | TES=6.5 h | SM=1.4 | PPA=44.00 USD/MWh | CF=0.5402
# das=68500 kWdc | P_ref=182.0 MWe | TES=6.5 h | SM=1.4 | PPA=44.05 USD/MWh | CF=0.5488
# das=63000 kWdc | P_ref=187.0 MWe | TES=6.5 h | SM=1.4 | PPA=44.10 USD/MWh | CF=0.5504
# das=63000 kWdc | P_ref=189.0 MWe | TES=6.5 h | SM=1.4 | PPA=44.19 USD/MWh | CF=0.5548
# das=68500 kWdc | P_ref=185.0 MWe | TES=6.5 h | SM=1.4 | PPA=44.20 USD/MWh | CF=0.5557
# das=68500 kWdc | P_ref=187.0 MWe | TES=6.5 h | SM=1.4 | PPA=44.30 USD/MWh | CF=0.5603
# das=70500 kWdc | P_ref=187.0 MWe | TES=6.5 h | SM=1.4 | PPA=44.41 USD/MWh | CF=0.5638
# das=70500 kWdc | P_ref=187.0 MWe | TES=7.0 h | SM=1.4 | PPA=44.44 USD/MWh | CF=0.5644
# das=63000 kWdc | P_ref=195.0 MWe | TES=6.5 h | SM=1.4 | PPA=44.51 USD/MWh | CF=0.5686
# das=63000 kWdc | P_ref=196.0 MWe | TES=6.5 h | SM=1.4 | PPA=44.56 USD/MWh | CF=0.5708
# das=63000 kWdc | P_ref=198.0 MWe | TES=6.5 h | SM=1.4 | PPA=44.67 USD/MWh | CF=0.5751
# das=63000 kWdc | P_ref=200.0 MWe | TES=6.5 h | SM=1.4 | PPA=44.79 USD/MWh | CF=0.5793
# das=79000 kWdc | P_ref=187.0 MWe | TES=7.0 h | SM=1.4 | PPA=44.83 USD/MWh | CF=0.5799
# das=68500 kWdc | P_ref=198.0 MWe | TES=6.5 h | SM=1.4 | PPA=44.88 USD/MWh | CF=0.5843
# das=79000 kWdc | P_ref=190.0 MWe | TES=6.5 h | SM=1.4 | PPA=45.00 USD/MWh | CF=0.5844
# das=74500 kWdc | P_ref=200.0 MWe | TES=6.5 h | SM=1.3 | PPA=45.01 USD/MWh | CF=0.5857
# das=85500 kWdc | P_ref=187.0 MWe | TES=6.5 h | SM=1.4 | PPA=45.18 USD/MWh | CF=0.5883
# das=79000 kWdc | P_ref=190.0 MWe | TES=6.5 h | SM=1.5 | PPA=45.37 USD/MWh | CF=0.5936
# das=86000 kWdc | P_ref=200.0 MWe | TES=6.5 h | SM=1.3 | PPA=45.68 USD/MWh | CF=0.6037
# das=84000 kWdc | P_ref=199.0 MWe | TES=6.5 h | SM=1.4 | PPA=45.76 USD/MWh | CF=0.6103
# das=85500 kWdc | P_ref=199.0 MWe | TES=6.5 h | SM=1.4 | PPA=45.92 USD/MWh | CF=0.6125
# das=91500 kWdc | P_ref=195.0 MWe | TES=6.5 h | SM=1.4 | PPA=46.06 USD/MWh | CF=0.6134
# das=91500 kWdc | P_ref=196.0 MWe | TES=6.5 h | SM=1.4 | PPA=46.13 USD/MWh | CF=0.6153
# das=96000 kWdc | P_ref=195.0 MWe | TES=7.0 h | SM=1.4 | PPA=46.28 USD/MWh | CF=0.6223
# das=91500 kWdc | P_ref=196.0 MWe | TES=6.5 h | SM=1.5 | PPA=46.62 USD/MWh | CF=0.6232
# das=94500 kWdc | P_ref=195.0 MWe | TES=7.0 h | SM=1.5 | PPA=46.70 USD/MWh | CF=0.6283
# das=93500 kWdc | P_ref=198.0 MWe | TES=6.5 h | SM=1.5 | PPA=46.92 USD/MWh | CF=0.6296
# das=94500 kWdc | P_ref=199.0 MWe | TES=7.0 h | SM=1.5 | PPA=46.99 USD/MWh | CF=0.6352
# das=97500 kWdc | P_ref=200.0 MWe | TES=10.5 h | SM=1.4 | PPA=47.26 USD/MWh | CF=0.6360
# das=107000 kWdc | P_ref=200.0 MWe | TES=10.5 h | SM=1.3 | PPA=47.67 USD/MWh | CF=0.6390
# das=107000 kWdc | P_ref=198.0 MWe | TES=10.5 h | SM=1.4 | PPA=47.77 USD/MWh | CF=0.6469
# das=105500 kWdc | P_ref=200.0 MWe | TES=10.5 h | SM=1.4 | PPA=47.86 USD/MWh | CF=0.6482
# das=106000 kWdc | P_ref=200.0 MWe | TES=10.5 h | SM=1.4 | PPA=47.88 USD/MWh | CF=0.6490
# das=125500 kWdc | P_ref=184.0 MWe | TES=10.5 h | SM=1.4 | PPA=48.40 USD/MWh | CF=0.6499
# das=128000 kWdc | P_ref=184.0 MWe | TES=11.5 h | SM=1.4 | PPA=48.84 USD/MWh | CF=0.6535
# das=129500 kWdc | P_ref=184.0 MWe | TES=10.5 h | SM=1.4 | PPA=48.88 USD/MWh | CF=0.6553
# das=129500 kWdc | P_ref=184.0 MWe | TES=11.5 h | SM=1.4 | PPA=49.06 USD/MWh | CF=0.6556
# das=129500 kWdc | P_ref=187.0 MWe | TES=11.5 h | SM=1.4 | PPA=49.27 USD/MWh | CF=0.6609
# das=130500 kWdc | P_ref=190.0 MWe | TES=11.0 h | SM=1.4 | PPA=49.43 USD/MWh | CF=0.6666
# das=131500 kWdc | P_ref=190.0 MWe | TES=11.0 h | SM=1.4 | PPA=49.48 USD/MWh | CF=0.6678
# das=131500 kWdc | P_ref=190.0 MWe | TES=11.0 h | SM=1.5 | PPA=49.87 USD/MWh | CF=0.6755
# das=129500 kWdc | P_ref=200.0 MWe | TES=11.5 h | SM=1.4 | PPA=50.18 USD/MWh | CF=0.6815
# das=136000 kWdc | P_ref=197.0 MWe | TES=10.5 h | SM=1.4 | PPA=50.47 USD/MWh | CF=0.6835
# das=137500 kWdc | P_ref=197.0 MWe | TES=10.5 h | SM=1.4 | PPA=50.55 USD/MWh | CF=0.6851
# das=129500 kWdc | P_ref=200.0 MWe | TES=11.0 h | SM=1.5 | PPA=50.56 USD/MWh | CF=0.6885
# das=129500 kWdc | P_ref=200.0 MWe | TES=12.0 h | SM=1.5 | PPA=50.72 USD/MWh | CF=0.6897
# das=138000 kWdc | P_ref=200.0 MWe | TES=10.5 h | SM=1.4 | PPA=50.80 USD/MWh | CF=0.6901
# das=138500 kWdc | P_ref=200.0 MWe | TES=10.5 h | SM=1.4 | PPA=50.98 USD/MWh | CF=0.6907
# das=139500 kWdc | P_ref=200.0 MWe | TES=10.5 h | SM=1.4 | PPA=51.04 USD/MWh | CF=0.6918
# das=140500 kWdc | P_ref=200.0 MWe | TES=10.5 h | SM=1.4 | PPA=51.10 USD/MWh | CF=0.6928
# das=143500 kWdc | P_ref=198.0 MWe | TES=11.0 h | SM=1.5 | PPA=51.82 USD/MWh | CF=0.7011
# das=143500 kWdc | P_ref=200.0 MWe | TES=11.0 h | SM=1.5 | PPA=51.99 USD/MWh | CF=0.7040
# das=143500 kWdc | P_ref=198.0 MWe | TES=13.0 h | SM=1.6 | PPA=52.67 USD/MWh | CF=0.7082
# das=158500 kWdc | P_ref=200.0 MWe | TES=13.0 h | SM=1.4 | PPA=53.60 USD/MWh | CF=0.7136
# das=156000 kWdc | P_ref=200.0 MWe | TES=12.5 h | SM=1.5 | PPA=53.67 USD/MWh | CF=0.7178
# das=158000 kWdc | P_ref=199.0 MWe | TES=13.0 h | SM=1.5 | PPA=53.94 USD/MWh | CF=0.7187
# das=161000 kWdc | P_ref=198.0 MWe | TES=11.0 h | SM=1.6 | PPA=54.52 USD/MWh | CF=0.7221
# das=161000 kWdc | P_ref=199.0 MWe | TES=11.0 h | SM=1.6 | PPA=54.58 USD/MWh | CF=0.7229
# das=199500 kWdc | P_ref=184.0 MWe | TES=10.5 h | SM=1.5 | PPA=58.57 USD/MWh | CF=0.7279
# das=199500 kWdc | P_ref=184.0 MWe | TES=13.0 h | SM=1.5 | PPA=58.79 USD/MWh | CF=0.7309
# das=203500 kWdc | P_ref=189.0 MWe | TES=11.0 h | SM=1.4 | PPA=59.13 USD/MWh | CF=0.7317
# das=201500 kWdc | P_ref=200.0 MWe | TES=11.5 h | SM=1.3 | PPA=59.26 USD/MWh | CF=0.7367
# das=201500 kWdc | P_ref=196.0 MWe | TES=13.0 h | SM=1.4 | PPA=59.43 USD/MWh | CF=0.7416
# das=199500 kWdc | P_ref=199.0 MWe | TES=11.0 h | SM=1.5 | PPA=59.75 USD/MWh | CF=0.7479
# das=199500 kWdc | P_ref=200.0 MWe | TES=12.0 h | SM=1.5 | PPA=59.92 USD/MWh | CF=0.7504
# das=210000 kWdc | P_ref=195.0 MWe | TES=13.0 h | SM=1.5 | PPA=61.21 USD/MWh | CF=0.7523
# das=210000 kWdc | P_ref=199.0 MWe | TES=13.0 h | SM=1.5 | PPA=61.55 USD/MWh | CF=0.7571
# das=213000 kWdc | P_ref=198.0 MWe | TES=11.0 h | SM=1.6 | PPA=62.36 USD/MWh | CF=0.7589
# das=213000 kWdc | P_ref=199.0 MWe | TES=12.5 h | SM=1.6 | PPA=62.53 USD/MWh | CF=0.7619
# das=221000 kWdc | P_ref=200.0 MWe | TES=12.5 h | SM=1.5 | PPA=63.54 USD/MWh | CF=0.7646
# das=234000 kWdc | P_ref=200.0 MWe | TES=13.0 h | SM=1.4 | PPA=65.37 USD/MWh | CF=0.7671
# das=233000 kWdc | P_ref=200.0 MWe | TES=10.5 h | SM=1.5 | PPA=65.61 USD/MWh | CF=0.7677
# das=235500 kWdc | P_ref=200.0 MWe | TES=11.0 h | SM=1.5 | PPA=66.12 USD/MWh | CF=0.7703
# das=237500 kWdc | P_ref=200.0 MWe | TES=12.5 h | SM=1.5 | PPA=66.43 USD/MWh | CF=0.7741
# das=241000 kWdc | P_ref=200.0 MWe | TES=11.5 h | SM=1.5 | PPA=67.25 USD/MWh | CF=0.7742
# das=241000 kWdc | P_ref=200.0 MWe | TES=13.0 h | SM=1.5 | PPA=67.37 USD/MWh | CF=0.7767
# das=243500 kWdc | P_ref=200.0 MWe | TES=12.5 h | SM=1.6 | PPA=68.07 USD/MWh | CF=0.7796
# das=258500 kWdc | P_ref=200.0 MWe | TES=13.0 h | SM=1.4 | PPA=70.09 USD/MWh | CF=0.7807
# das=262500 kWdc | P_ref=199.0 MWe | TES=13.0 h | SM=1.4 | PPA=71.03 USD/MWh | CF=0.7817
# das=263500 kWdc | P_ref=200.0 MWe | TES=13.0 h | SM=1.4 | PPA=71.21 USD/MWh | CF=0.7833
#
# Best-by-PPA candidate:
# das=50500 kWdc | P_ref=124.0 MWe | TES=6.5 h | SM=1.5 | PPA=42.50 USD/MWh | CF=0.3847
#
# Saved ALL trials to: C:\Users\ardia\OneDrive - KTH\1. Large Scale Solar\Project\Tower_Hybrid_PV\ga_trials.csv
